# %%
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as pt
import seaborn as sns

# %%
file='movie_actors.csv'
df_movie_actors = pd.read_csv(file)

# %%
df_movie_actors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165130 entries, 0 to 165129
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   movie_id            165130 non-null  int64
#  1   movie_title         165130 non-null  object
#  2   movie_popularity    165130 non-null  float64
#  3   movie_release_date  165130 non-null  object
#  4   movie_budget        165130 non-null  int64
#  5   movie_revenue       165130 non-null  int64
#  6   actor_id            165130 non-null  int64
#  7   actor_name          165130 non-null  object
#  8   actor_order         165130 non-null  int64
#  9   actor_gender        165130 non-null  int64
# dtypes: float64(1), int64(6), object(3)
# memory usage: 12.6+ MB

# %%
df_movie_actors.head()
# Out:
#    movie_id               movie_title  movie_popularity movie_release_date  \
# 0     19185  Night of the Living Dead              33.5         1990-10-19
# 1     19185  Night of the Living Dead              33.5         1990-10-19
# 2     19185  Night of the Living Dead              33.5         1990-10-19
# 3     19185  Night of the Living Dead              33.5         1990-10-19
# 4     19185  Night of the Living Dead              33.5         1990-10-19
#
#    movie_budget  movie_revenue  actor_id        actor_name  actor_order  \
# 0       4200000        5835247     11768  Patricia Tallman            0
# 1       4200000        5835247     19384         Tony Todd            1
# 2       4200000        5835247     27736        Tom Towles            2
# 3       4200000        5835247     90653    McKee Anderson            3
# 4       4200000        5835247     27737      Bill Moseley            4
#
#    actor_gender
# 0             1
# 1             2
# 2             2
# ...

# %%
df_movie_actors['actor_gender'].value_counts()
# Out:
# actor_gender
# 2    80377
# 0    43573
# 1    41137
# 3       43
# Name: count, dtype: int64

# %%
#Most Common Genders is '2'

# %%
df_movie_actors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165130 entries, 0 to 165129
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   movie_id            165130 non-null  int64
#  1   movie_title         165130 non-null  object
#  2   movie_popularity    165130 non-null  float64
#  3   movie_release_date  165130 non-null  object
#  4   movie_budget        165130 non-null  int64
#  5   movie_revenue       165130 non-null  int64
#  6   actor_id            165130 non-null  int64
#  7   actor_name          165130 non-null  object
#  8   actor_order         165130 non-null  int64
#  9   actor_gender        165130 non-null  int64
# dtypes: float64(1), int64(6), object(3)
# memory usage: 12.6+ MB

# %%
df_movie_actors[df_movie_actors['movie_title']=='Furious 7']
# Out:
#         movie_id movie_title  movie_popularity movie_release_date  \
# 127694    168259   Furious 7            88.169         2015-04-01
# 127695    168259   Furious 7            88.169         2015-04-01
# 127696    168259   Furious 7            88.169         2015-04-01
# 127697    168259   Furious 7            88.169         2015-04-01
# 127698    168259   Furious 7            88.169         2015-04-01
# 127699    168259   Furious 7            88.169         2015-04-01
# 127700    168259   Furious 7            88.169         2015-04-01
# 127701    168259   Furious 7            88.169         2015-04-01
# 127702    168259   Furious 7            88.169         2015-04-01
# 127703    168259   Furious 7            88.169         2015-04-01
# 127704    168259   Furious 7            88.169         2015-04-01
# 127705    168259   Furious 7            88.169         2015-04-01
# 127706    168259   Furious 7            88.169         2015-04-01
# ...

# %%
df_movie_actors[(df_movie_actors['movie_title']=='Furious 7') & (df_movie_actors['actor_gender']==2)]
#Movie with '2' gender only
# Out:
#         movie_id movie_title  movie_popularity movie_release_date  \
# 127694    168259   Furious 7            88.169         2015-04-01
# 127695    168259   Furious 7            88.169         2015-04-01
# 127696    168259   Furious 7            88.169         2015-04-01
# 127698    168259   Furious 7            88.169         2015-04-01
# 127699    168259   Furious 7            88.169         2015-04-01
# 127701    168259   Furious 7            88.169         2015-04-01
# 127702    168259   Furious 7            88.169         2015-04-01
# 127705    168259   Furious 7            88.169         2015-04-01
# 127706    168259   Furious 7            88.169         2015-04-01
# 127708    168259   Furious 7            88.169         2015-04-01
# 127710    168259   Furious 7            88.169         2015-04-01
# 127711    168259   Furious 7            88.169         2015-04-01
# 127712    168259   Furious 7            88.169         2015-04-01
# ...

# %%
#Leading actors in Furious 7
df_movie_actors[(df_movie_actors['actor_order']<5) & (df_movie_actors['movie_title']=='Furious 7')]
# Out:
#         movie_id movie_title  movie_popularity movie_release_date  \
# 127694    168259   Furious 7            88.169         2015-04-01
# 127695    168259   Furious 7            88.169         2015-04-01
# 127696    168259   Furious 7            88.169         2015-04-01
# 127697    168259   Furious 7            88.169         2015-04-01
# 127698    168259   Furious 7            88.169         2015-04-01
#
#         movie_budget  movie_revenue  actor_id          actor_name  \
# 127694     190000000     1515047671     12835          Vin Diesel
# 127695     190000000     1515047671      8167         Paul Walker
# 127696     190000000     1515047671     18918      Dwayne Johnson
# 127697     190000000     1515047671     17647  Michelle Rodriguez
# 127698     190000000     1515047671      8169       Tyrese Gibson
#
#         actor_order  actor_gender
# 127694            0             2
# 127695            1             2
# 127696            2             2
# ...

# %%
df_movie_actors['movie_release_date']=pd.to_datetime(df_movie_actors['movie_release_date'])
df_movie_actors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165130 entries, 0 to 165129
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   movie_id            165130 non-null  int64
#  1   movie_title         165130 non-null  object
#  2   movie_popularity    165130 non-null  float64
#  3   movie_release_date  165130 non-null  datetime64[ns]
#  4   movie_budget        165130 non-null  int64
#  5   movie_revenue       165130 non-null  int64
#  6   actor_id            165130 non-null  int64
#  7   actor_name          165130 non-null  object
#  8   actor_order         165130 non-null  int64
#  9   actor_gender        165130 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(6), object(2)
# memory usage: 12.6+ MB

# %%
df_movie_actors.head()
# Out:
#    movie_id               movie_title  movie_popularity movie_release_date  \
# 0     19185  Night of the Living Dead              33.5         1990-10-19
# 1     19185  Night of the Living Dead              33.5         1990-10-19
# 2     19185  Night of the Living Dead              33.5         1990-10-19
# 3     19185  Night of the Living Dead              33.5         1990-10-19
# 4     19185  Night of the Living Dead              33.5         1990-10-19
#
#    movie_budget  movie_revenue  actor_id        actor_name  actor_order  \
# 0       4200000        5835247     11768  Patricia Tallman            0
# 1       4200000        5835247     19384         Tony Todd            1
# 2       4200000        5835247     27736        Tom Towles            2
# 3       4200000        5835247     90653    McKee Anderson            3
# 4       4200000        5835247     27737      Bill Moseley            4
#
#    actor_gender
# 0             1
# 1             2
# 2             2
# ...

# %%
df_movie_actors['movie_release_date'].min()
# Out:
# Timestamp('1990-01-18 00:00:00')

# %%
df_movie_actors['movie_release_date'].max()
# Out:
# Timestamp('2021-06-15 00:00:00')

# %%
df_movie_actors['movie_release_year']=df_movie_actors['movie_release_date'].dt.year

# %%
df_movie_actors['movie_release_year']
# Out:
# 0         1990
# 1         1990
# 2         1990
# 3         1990
# 4         1990
#           ...
# 165125    2021
# 165126    2021
# 165127    2021
# 165128    2021
# 165129    2021
# Name: movie_release_year, Length: 165130, dtype: int32

# %%
df_movie_actors.nlargest(n=10, columns=['movie_revenue'])
# Out:
#         movie_id        movie_title  movie_popularity movie_release_date  \
# 157607    299534  Avengers: Endgame            256.12         2019-04-24
# 157608    299534  Avengers: Endgame            256.12         2019-04-24
# 157609    299534  Avengers: Endgame            256.12         2019-04-24
# 157610    299534  Avengers: Endgame            256.12         2019-04-24
# 157611    299534  Avengers: Endgame            256.12         2019-04-24
# 157612    299534  Avengers: Endgame            256.12         2019-04-24
# 157613    299534  Avengers: Endgame            256.12         2019-04-24
# 157614    299534  Avengers: Endgame            256.12         2019-04-24
# 157615    299534  Avengers: Endgame            256.12         2019-04-24
# 157616    299534  Avengers: Endgame            256.12         2019-04-24
#
#         movie_budget  movie_revenue  actor_id            actor_name  \
# 157607     356000000     2797800564      3223     Robert Downey Jr.
# ...

# %%
sort_movie_revenue=df_movie_actors.sort_values(by='movie_revenue')
sort_movie_revenue.groupby('movie_release_year').last()
# Out:
#                     movie_id                                    movie_title  \
# movie_release_year
# 1990                     251                                          Ghost
# 1991                     280                     Terminator 2: Judgment Day
# 1992                     812                                        Aladdin
# 1993                     329                                  Jurassic Park
# 1994                    8587                                  The Lion King
# 1995                     862                                      Toy Story
# 1996                     602                               Independence Day
# 1997                     597                                        Titanic
# 1998                      95                                     Armageddon
# 1999                    1893      Star Wars: Episode I - The Phantom Menace
# 2000                     955                         Mission: Impossible II
# ...

# %%
reordered_data=df_movie_actors[['actor_name','movie_release_year','movie_release_date']]
reordered_data
# Out:
#               actor_name  movie_release_year movie_release_date
# 0       Patricia Tallman                1990         1990-10-19
# 1              Tony Todd                1990         1990-10-19
# 2             Tom Towles                1990         1990-10-19
# 3         McKee Anderson                1990         1990-10-19
# 4           Bill Moseley                1990         1990-10-19
# ...                  ...                 ...                ...
# 165125       Julio Arana                2021         2021-03-05
# 165126     Sipho Nxasana                2021         2021-02-03
# 165127      Purple Spice                2021         2021-02-03
# 165128      Rafa Moreira                2021         2021-02-21
# 165129        Ally Davis                2021         2021-02-21
#
# [165130 rows x 3 columns]

# %%
df_movie_actors.groupby('movie_release_year').nunique()
# Out:
#                     movie_id  movie_title  movie_popularity  \
# movie_release_year
# 1990                      71           71                71
# 1991                      91           91                91
# 1992                      80           80                80
# 1993                     109          109               109
# 1994                      90           90                88
# 1995                     114          114               113
# 1996                     115          115               114
# 1997                     122          122               122
# 1998                     134          134               134
# 1999                     149          149               149
# 2000                     144          144               144
# 2001                     151          151               150
# 2002                     160          160               159
# 2003                     163          163               163
# ...

# %%
df_movie_actors['movie_budget'].hist()
# Out:
# <Axes: >

# %%
df_movie_actors
# Out:
#         movie_id               movie_title  movie_popularity  \
# 0          19185  Night of the Living Dead              33.5
# 1          19185  Night of the Living Dead              33.5
# 2          19185  Night of the Living Dead              33.5
# 3          19185  Night of the Living Dead              33.5
# 4          19185  Night of the Living Dead              33.5
# ...          ...                       ...               ...
# 165125    804568           Fruits of Labor               0.6
# 165126    800234                     Lunch               0.6
# 165127    800234                     Lunch               0.6
# 165128    799413         This Could Be You               0.6
# 165129    799413         This Could Be You               0.6
#
#        movie_release_date  movie_budget  movie_revenue  actor_id  \
# 0              1990-10-19       4200000        5835247     11768
# 1              1990-10-19       4200000        5835247     19384
# ...

# %%
sns.scatterplot(x='movie_budget', y='movie_revenue', data=df_movie_actors)
# Out:
# <Axes: xlabel='movie_budget', ylabel='movie_revenue'>

# %%
sns.jointplot(x='movie_budget', y='movie_revenue', data=df_movie_actors)

# %%
df_movie_actors.groupby('actor_name')['movie_revenue'].sum().nlargest(10)
# Out:
# actor_name
# Stan Lee              30513647785
# Samuel L. Jackson     26563727612
# Frank Welker          19127637846
# Jess Harnell          17965605716
# Scarlett Johansson    16423470258
# Warwick Davis         15904065259
# Alan Tudyk            15574055338
# Mickie McGowan        15396836203
# John Ratzenberger     14911889467
# Bob Bergen            14796273137
# Name: movie_revenue, dtype: int64
